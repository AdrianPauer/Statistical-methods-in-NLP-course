# %%
import pandas as pd
import numpy as np
import requests
import math
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url1 = 'https://ufal.mff.cuni.cz/~pecina/courses/npfl067/data/TEXTEN1.txt'
url2 = 'https://ufal.mff.cuni.cz/~pecina/courses/npfl067/data/TEXTCZ1.txt'
url3 = 'https://ufal.mff.cuni.cz/~pecina/courses/npfl067/data/TEXTEN1.ptg'
url4 = 'https://ufal.mff.cuni.cz/~pecina/courses/npfl067/data/TEXTCZ1.ptg'

# %% [markdown]
# ## **1) Best friends**

# %%
def get_data(url):
  " returns list of worlds and list of non frequent data"

  data = requests.get(url)
  data.encoding = 'iso-8859-2'
  data = data.text.split('\n')[:-1]

  # find frequent words
  vocab,counts = np.unique(data, return_counts=True)
  non_frequent = vocab[counts < 10]

  return data, non_frequent

# %%
def put_to_dict(key, dc):
  # put key in dictionary
  if  key not in dc:
    dc[key] = 1
  else:
    dc[key] +=1

def compute_counts(data, distance):
  # compute count of bigrams and unigrams
  text_length = len(data)
  pairs_counts = dict()
  word_counts = dict()

  for i in range(text_length-1):

    if distance == 50:
      # for distant pairs
      lb = max(0, i-distance)
      up = min(text_length, i+distance +1)
      word1 = data[i]
      put_to_dict(word1, word_counts)

      for j in range(lb, up):
        if j == i or j == i+1 or j == i-1 : continue
        word2 = data[j]
        put_to_dict((word1, word2), pairs_counts)

    else:
      # for non-distant bigrams
      word1 = data[i]
      word2 = data[i+1]

      put_to_dict((word1, word2), pairs_counts)
      put_to_dict(word1, word_counts)

  put_to_dict(data[-1], word_counts)

  return word_counts, pairs_counts

# %%
def compute_PMI(unigram_c, bigram_c):
  # compute PMI based on bigram and unigram distributions for bigrams from which both words apperars >= 10 times

  PMI = dict()
  N_u = sum(unigram_c.values())
  N_b = sum(bigram_c.values())

  for pair,count in bigram_c.items():
    word1, word2 = pair
    if unigram_c[word1] < 10 or unigram_c[word2] < 10: continue

    joint_prob = count/N_b
    PMI[pair] = math.log(joint_prob / (unigram_c[word1]/N_u * unigram_c[word2]/N_u), 2)
  return PMI

# %%
def compute_pmi_for_dataset(dataset,distance):
  # returns dataframe for pmi and bigrams obtained from dataset
  unigram_p, joint_p = compute_counts(dataset, distance)
  pmi = compute_PMI(unigram_p, joint_p)
  df = pd.DataFrame(list(pmi.items()), columns=['pair', 'PMI'])
  return df

# %%
# load data
data_CZ, non_freq_CZ = get_data(url2)
data_EN, non_freq_EN = get_data(url1)

# %%
# compute PMI for czech dataset
df_bigrams_CZ = compute_pmi_for_dataset(data_CZ, 2)

# %%
# show 10 pairs with negaitve PMI
df_bigrams_CZ[df_bigrams_CZ['PMI']<0][:10]
# Out:
#             pair       PMI
# 22   (začala, ,) -0.310172
# 48    (,, členů) -0.688684
# 76        (,, v) -0.369542
# 83       (LN, .) -1.105118
# 93       (a, že) -0.008790
# 134       (., a) -2.119988
# 137  (., letech) -0.193345
# 139       (., E) -0.419227
# 142       (", v) -0.865643
# 150  (komise, a) -0.275223

# %%
# show best 20 pairs for czech dataset
df_bigrams_CZ.sort_values(by = 'PMI', ascending=False)[:20]
# Out:
#                              pair        PMI
# 7251              (Hamburger, SV)  14.288950
# 2349               (Los, Angeles)  14.062442
# 16869           (Johna, Newcomba)  13.762882
# 17205            (Č., Budějovice)  13.633599
# 24770                (série, ATP)  13.468968
# 24874          (turnajové, série)  13.434411
# 3811               (Tomáš, Ježek)  13.428981
# 8449             (Lidové, noviny)  13.329922
# 8862            (Lidových, novin)  13.271028
# 2705          (veřejného, mínění)  13.062442
# 6679             (teplota, minus)  12.981522
# 3738           (Ján, Čarnogurský)  12.955527
# 9152            (jaderné, zbraně)  12.955527
# 16494             (Milan, Máčala)  12.897811
# 1204             (lidských, práv)  12.862877
# 8809           (společném, státě)  12.708434
# 16431    (akciových, společností)  12.692492
# 7239                (Pohár, UEFA)  12.625378
# 2726   (privatizačních, projektů)  12.615677
# 13948             (George, Bushe)  12.603010

# %%
# compute pmi for distant pairs czech dataset
df_distant_CZ = compute_pmi_for_dataset(data_CZ, 50)

# %%
df_distant_CZ.sort_values(by = 'PMI', ascending=False)[:20]
# Out:
#                          pair       PMI
# 994100         (výher, výher)  9.855555
# 714065             (žel, žel)  9.136365
# 294204             (13h, 13h)  8.855555
# 640194   (Sandžaku, Sandžaku)  8.826409
# 1381966      (Petrof, Petrof)  8.785767
# 543726    (Bělehrad, Benfica)  8.688906
# 543860    (Benfica, Bělehrad)  8.688906
# 212728             (CIA, CIA)  8.504481
# 227073             (IFS, IFS)  8.437844
# 543861       (Benfica, Atény)  8.340982
# 294206        (13h, zataženo)  8.340982
# 543760       (Atény, Benfica)  8.340982
# 294288        (zataženo, 13h)  8.340982
# 294205           (13h, skoro)  8.322367
# 294268           (skoro, 13h)  8.322367
# 727259               (39, 39)  8.300340
# 543756      (Atény, Bělehrad)  8.266982
# 994174            (IV, výher)  8.266982
# 994146            (výher, IV)  8.266982
# 543722      (Bělehrad, Atény)  8.266982

# %%
# bigrams english dataset
df_bigrams_EN = compute_pmi_for_dataset(data_EN, 2)
df_bigrams_EN.sort_values(by = 'PMI', ascending=False)[:20]
# Out:
#                            pair        PMI
# 9935                (La, Plata)  14.169370
# 8263                (Asa, Gray)  14.031867
# 7500            (Fritz, Muller)  13.362016
# 2337             (worth, while)  13.332869
# 3736           (faced, tumbler)  13.262480
# 8953         (lowly, organised)  13.216899
# 191        (Malay, Archipelago)  13.110477
# 19636        (shoulder, stripe)  13.053893
# 3523           (Great, Britain)  12.914557
# 6782           (United, States)  12.847442
# 3732         (English, carrier)  12.525514
# 29996      (specially, endowed)  12.401817
# 3653                   (Sir, J)  12.377364
# 15919           (branched, off)  12.377364
# 27471       (mental, qualities)  12.362016
# 8234             (de, Candolle)  12.362016
# 7917   (Galapagos, Archipelago)  12.344942
# 10957             (red, clover)  12.323880
# 13642     (self, fertilisation)  12.316928
# 30682    (systematic, affinity)  12.251833

# %%
# pmi for distant pairs english dataset
df_distant_EN = compute_pmi_for_dataset(data_EN, 50)
df_distant_EN.sort_values(by = 'PMI', ascending=False)[:20]
# Out:
#                                    pair       PMI
# 1189784                (floated, dried)  8.692331
# 1189935                (dried, floated)  8.692331
# 1190282                  (dried, dried)  8.303288
# 1189651              (floated, floated)  8.192257
# 1190392             (germinated, dried)  8.165785
# 1190286             (dried, germinated)  8.165785
# 375380                   (heath, heath)  8.060838
# 384080                 (clover, clover)  8.026448
# 1190387           (germinated, floated)  7.969865
# 1190248           (floated, germinated)  7.969865
# 1172644              (eastern, Pacific)  7.886809
# 1172699              (Pacific, eastern)  7.886809
# 861150          (vibracula, avicularia)  7.854387
# 861064          (avicularia, vibracula)  7.854387
# 1190352                   (days, dried)  7.817861
# 1190284                   (dried, days)  7.817861
# 1310471  (metamorphosed, metamorphosed)  7.817861
# 599822                     (cave, cave)  7.817861
# 384134                   (heads, heads)  7.805889
# 400805                       (THE, THE)  7.777219

# %% [markdown]
# #2) Word classes

# %%
def get_data(url):
  # returns list of words and tags of data

  data = requests.get(url)
  data.encoding = 'iso-8859-2'
  lines = data.text.split('\n')[:-1]
  words,tags = [], []
  for line in lines:
    word, tag = line.split('/')
    words.append(word)
    tags.append(tag)

  return words, tags

# %%
def compute_counts(words):
  # compute bigram and unigram counts

  bigram_counts = dict()
  unigram_counts = dict()

  for i in range(len(words) - 1):
      w1, w2 = words[i], words[i + 1]

      bigram_counts[(w1, w2)] = bigram_counts.get((w1, w2), 0) + 1
      unigram_counts[w1] = unigram_counts.get(w1, 0) + 1

  unigram_counts[words[-1]] = unigram_counts.get(words[-1], 0) + 1

  return unigram_counts, bigram_counts

# %%
def calculate_q(bigrams_c, uni_cl, uni_cr, N):
  # returns table of pmi for bigrams

  q_k = dict()
  for pair,count in bigrams_c.items():
    w1, w2 = pair
    q_k[pair] = count/N * math.log(N * count / (uni_cl[w1] * uni_cr[w2]), 2)
  return q_k

# %%
def calculate_s(current_classes, q_k, uni_cl, uni_cr):
  # returns table of subtractions

  s_k = dict()
  for word in current_classes:
    s_k[word] = sum(q_k.get((wordL, word), 0) for wordL in uni_cl.keys()) \
    + sum(q_k.get((word, wordR), 0) for wordR in uni_cr.keys()) \
    - q_k.get((word, word), 0)
  return s_k

# %%
def compute_loss(current_classes, q_k, s_k, uni_cl, uni_cr, bigrams_c, N):
  # returns table of losses
  L_ab = dict()

  for i in range(len(current_classes)):
    for j in range(i+1, len(current_classes)):
      a,b = current_classes[i], current_classes[j]

      # sums computation
      sum_q_l_ab = 0
      uni_c_rab = uni_cr[a] + uni_cr[b]

      for wordL in uni_cl.keys():
        if wordL == a or wordL == b: continue
        bigr_c_lab = bigrams_c.get((wordL, a),0) + bigrams_c.get((wordL, b),0)

        if bigr_c_lab == 0: continue

        mi = bigr_c_lab/N * math.log(N * bigr_c_lab / (uni_cl[wordL] * uni_c_rab), 2)
        sum_q_l_ab += mi

      sum_q_ab_r = 0
      uni_c_lab = uni_cl[a] + uni_cl[b]

      for wordR in uni_cr.keys():
        if wordR == a or wordR == b: continue
        bigr_c_rab = bigrams_c.get((a, wordR),0) + bigrams_c.get((b, wordR),0)

        if bigr_c_rab == 0: continue

        mi = bigr_c_rab/N * math.log(N * bigr_c_rab / (uni_c_lab * uni_cr[wordR]), 2)
        sum_q_ab_r += mi

      # compute q_ab_ab
      bigr_c_abab = bigrams_c.get((a, b),0)  + bigrams_c.get((b, a),0) + bigrams_c.get((a, a),0) + bigrams_c.get((b, b),0)
      if bigr_c_abab == 0:
        q_ab_ab = 0
      else:
        q_ab_ab = bigr_c_abab/N * math.log(N * bigr_c_abab / (uni_c_lab * uni_c_rab), 2)

      L_ab[(a,b)] = s_k[a] + s_k[b] - q_k.get((a,b), 0) - q_k.get((b,a), 0) - q_ab_ab - sum_q_ab_r - sum_q_l_ab

  return L_ab

# %%
def merge_classes(best_a, best_b, classes, bigrams_c, uni_cl, uni_cr):

  # merge classes for a, b
  classes[best_a] = classes[best_a] + ' + ' + classes[best_b]
  del classes[best_b]

  # update unigram counts
  uni_cl[best_a] += uni_cl[best_b]
  del uni_cl[best_b]

  uni_cr[best_a] += uni_cr[best_b]
  del uni_cr[best_b]

  # update bigram counts
  updated_bigrams = bigrams_c.copy()

  for pair,count in bigrams_c.items():
    w1, w2 = pair
    if w1 == best_b and w2 == best_b:
      updated_bigrams[(best_a, best_a)] = bigrams_c.get((best_a, best_a),0) + count
      del updated_bigrams[(best_b, best_b)]

    if w1 == best_b and w2 != best_b:
      updated_bigrams[(best_a, w2)] = bigrams_c.get((best_a, w2),0) + count
      del updated_bigrams[(best_b, w2)]

    if w1 != best_b and w2 == best_b:
      updated_bigrams[(w1, best_a)] = bigrams_c.get((w1, best_a),0) + count
      del updated_bigrams[(w1, best_b)]

  return classes, updated_bigrams, uni_cl, uni_cr

# %%
def browns_clustering(words_to_cluster, name, limit):
  # initialise data structures
  history = dict()
  unigrams_c, bigrams_c = compute_counts(words_to_cluster)
  uni_cl = dict()
  uni_cr = dict()
  N = len(words_to_cluster)-1 # number of bigrams
  classes = dict()

  # compute ckl(), ckr()
  for word in unigrams_c.keys():
    uni_cl[word] = unigrams_c[word]
    uni_cr[word] = unigrams_c[word]

  # handle beginning and end
  uni_cl[words_to_cluster[-1]] -= 1
  uni_cr[words_to_cluster[0]] -= 1

  # init classes
  for word,count in unigrams_c.items():
    if count >= limit:
      classes[word] = word

  while len(classes) > 1:
    # compute q_k
    print('Computing q and s')
    q_k = calculate_q(bigrams_c, uni_cl, uni_cr, N)
    current_classes = list(classes.keys())

    # compute s_k
    s_k = calculate_s(current_classes, q_k, uni_cl, uni_cr)
    print(f'Computing loss table ..., actual mi {sum(q_k.values())}')

    # compute losses
    L_ab = compute_loss(current_classes, q_k, s_k, uni_cl, uni_cr, bigrams_c, N)

    # choose best pair to merge
    best_pair = min(L_ab, key=L_ab.get)
    best_a, best_b = best_pair
    print(f'Best pair to merge : {best_a}, {best_b} with loss : {L_ab[best_pair]}' )
    print('-' * 100 + '\n')

    # merge classes + update counts
    classes, bigrams_c, uni_cl, uni_cr = merge_classes(best_a, best_b, classes, bigrams_c, uni_cl, uni_cr)
    history[len(classes)] = best_pair
    print(f'Number of classes : {len(classes)}')

    # save 15 classes
    if len(classes) == 15:
      # Save dictionary
      with open(f'15_classes_{name}.txt', "w") as file:
        for key, value in classes.items():
            file.write(f"{key}: {value}\n")

  # save history
  with open(f'history_{name}.txt', "w") as file:
          file.write(f"number of classes: pair to merge\n")
          for key, value in history.items():
              file.write(f"{key}: {value}\n")

# %%
wordsEN, tagsEN= get_data(url3)
wordsCZ, tagsCZ= get_data(url4)

# %%
# perform clutering for english data
browns_clustering(wordsEN[:8000], 'EN', 10)
# Out:
# Computing q and s
# Computing loss table ..., actual mi 4.996336755075334
# Best pair to merge : subject, case with loss : 0.0021968411387180385
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 111
# Computing q and s
# Computing loss table ..., actual mi 4.994139913936615
# Best pair to merge : may, cannot with loss : 0.0026694731952487914
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 110
# Computing q and s
# Computing loss table ..., actual mi 4.991470440741367
# Best pair to merge : structure, individuals with loss : 0.0026751435455560704
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 109
# Computing q and s
# Computing loss table ..., actual mi 4.9887952971958125
# Best pair to merge : It, there with loss : 0.003479835349871169
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 108
# Computing q and s
# Computing loss table ..., actual mi 4.985315461845939
# Best pair to merge : even, less with loss : 0.0036560960742388522
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 107
# Computing q and s
# Computing loss table ..., actual mi 4.981659365771695
# Best pair to merge : variation, nature with loss : 0.003691412046720634
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 106
# Computing q and s
# Computing loss table ..., actual mi 4.977967953724972
# Best pair to merge : shall, see with loss : 0.003898283141534044
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 105
# Computing q and s
# Computing loss table ..., actual mi 4.97406967058344
# Best pair to merge : short, slight with loss : 0.003906127328145586
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 104
# Computing q and s
# Computing loss table ..., actual mi 4.9701635432552935
# Best pair to merge : certain, distinct with loss : 0.00399265587589627
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 103
# Computing q and s
# Computing loss table ..., actual mi 4.966170887379398
# Best pair to merge : such, manner with loss : 0.004241939523557966
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 102
# Computing q and s
# Computing loss table ..., actual mi 4.961928947855839
# Best pair to merge : must, can with loss : 0.004263460731611445
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 101
# Computing q and s
# Computing loss table ..., actual mi 4.957665487124228
# Best pair to merge : subject, state with loss : 0.004277198598594146
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 100
# Computing q and s
# Computing loss table ..., actual mi 4.953388288525635
# Best pair to merge : what, differ with loss : 0.004299332357240053
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 99
# Computing q and s
# Computing loss table ..., actual mi 4.949088956168395
# Best pair to merge : ), cases with loss : 0.0044569926808855145
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 98
# Computing q and s
# Computing loss table ..., actual mi 4.944631963487511
# Best pair to merge : me, only with loss : 0.004478586690182532
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 97
# Computing q and s
# Computing loss table ..., actual mi 4.940153376797331
# Best pair to merge : nearly, how with loss : 0.004540771818290205
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 96
# Computing q and s
# Computing loss table ..., actual mi 4.9356126049790445
# Best pair to merge : domesticated, domestic with loss : 0.00456411756848089
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 95
# Computing q and s
# Computing loss table ..., actual mi 4.931048487410565
# Best pair to merge : varieties, races with loss : 0.00461394265842122
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 94
# Computing q and s
# Computing loss table ..., actual mi 4.926434544752143
# Best pair to merge : if, when with loss : 0.004763427842353413
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 93
# Computing q and s
# Computing loss table ..., actual mi 4.92167111690979
# Best pair to merge : (, than with loss : 0.004873414402153102
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 92
# Computing q and s
# Computing loss table ..., actual mi 4.91679770250764
# Best pair to merge : do, believe with loss : 0.004949822233208317
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 91
# Computing q and s
# Computing loss table ..., actual mi 4.91184788027443
# Best pair to merge : my, great with loss : 0.005126188804946009
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 90
# Computing q and s
# Computing loss table ..., actual mi 4.906721691469482
# Best pair to merge : will, could with loss : 0.005601348554720328
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 89
# Computing q and s
# Computing loss table ..., actual mi 4.90112034291476
# Best pair to merge : structure, variation with loss : 0.005616969195067784
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 88
# Computing q and s
# Computing loss table ..., actual mi 4.895503373719693
# Best pair to merge : facts, plants with loss : 0.005690351254102485
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 87
# Computing q and s
# Computing loss table ..., actual mi 4.889813022465591
# Best pair to merge : :, between with loss : 0.005755987282144007
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 86
# Computing q and s
# Computing loss table ..., actual mi 4.884057035183451
# Best pair to merge : its, different with loss : 0.005812004625037264
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 85
# Computing q and s
# Computing loss table ..., actual mi 4.878245030558413
# Best pair to merge : In, The with loss : 0.005976428823747423
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 84
# Computing q and s
# Computing loss table ..., actual mi 4.8722686017346595
# Best pair to merge : conditions, breeds with loss : 0.0060708153169953365
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 83
# Computing q and s
# Computing loss table ..., actual mi 4.866197786417665
# Best pair to merge : short, long with loss : 0.006272470950567221
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 82
# Computing q and s
# Computing loss table ..., actual mi 4.859925315467093
# Best pair to merge : these, each with loss : 0.006341510670282335
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 81
# Computing q and s
# Computing loss table ..., actual mi 4.853583804796811
# Best pair to merge : may, would with loss : 0.006574811563169233
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 80
# Computing q and s
# Computing loss table ..., actual mi 4.847008993233636
# Best pair to merge : any, very with loss : 0.0068283956796606066
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 79
# Computing q and s
# Computing loss table ..., actual mi 4.8401805975539745
# Best pair to merge : many, most with loss : 0.006841210922396044
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 78
# Computing q and s
# Computing loss table ..., actual mi 4.833339386631581
# Best pair to merge : often, so with loss : 0.007052457001314625
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 77
# Computing q and s
# Computing loss table ..., actual mi 4.826286929630264
# Best pair to merge : we, they with loss : 0.007133784495671414
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 76
# Computing q and s
# Computing loss table ..., actual mi 4.819153145134593
# Best pair to merge : much, what with loss : 0.007268272740868765
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 75
# Computing q and s
# Computing loss table ..., actual mi 4.811884872393726
# Best pair to merge : do, shall with loss : 0.0077617338304270984
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 74
# Computing q and s
# Computing loss table ..., actual mi 4.804123138563302
# Best pair to merge : more, even with loss : 0.007964301957705158
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 73
# Computing q and s
# Computing loss table ..., actual mi 4.7961588366055965
# Best pair to merge : it, It with loss : 0.008141855794034914
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 72
# Computing q and s
# Computing loss table ..., actual mi 4.7880169808115625
# Best pair to merge : ), animals with loss : 0.008022489415411355
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 71
# Computing q and s
# Computing loss table ..., actual mi 4.779994491396153
# Best pair to merge : certain, an with loss : 0.008263353461618113
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 70
# Computing q and s
# Computing loss table ..., actual mi 4.771731137934532
# Best pair to merge : may, must with loss : 0.008614868156078197
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 69
# Computing q and s
# Computing loss table ..., actual mi 4.763116269778455
# Best pair to merge : such, wild with loss : 0.008615058602382888
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 68
# Computing q and s
# Computing loss table ..., actual mi 4.754501211176073
# Best pair to merge : all, nearly with loss : 0.009405070003457094
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 67
# Computing q and s
# Computing loss table ..., actual mi 4.745096141172615
# Best pair to merge : (, but with loss : 0.009567895041032809
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 66
# Computing q and s
# Computing loss table ..., actual mi 4.73552824613158
# Best pair to merge : subject, conditions with loss : 0.009646334537111029
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 65
# Computing q and s
# Computing loss table ..., actual mi 4.7258819115944695
# Best pair to merge : one, other with loss : 0.009720575454398948
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 64
# Computing q and s
# Computing loss table ..., actual mi 4.716161336140072
# Best pair to merge : our, my with loss : 0.00977297951482238
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 63
# Computing q and s
# Computing loss table ..., actual mi 4.70638835662525
# Best pair to merge : me, at with loss : 0.009940644158678822
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 62
# Computing q and s
# Computing loss table ..., actual mi 4.696447712466573
# Best pair to merge : some, these with loss : 0.010203791266928997
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 61
# Computing q and s
# Computing loss table ..., actual mi 4.68624392119964
# Best pair to merge : several, its with loss : 0.010270554438372239
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 60
# Computing q and s
# Computing loss table ..., actual mi 4.675973366761262
# Best pair to merge : species, varieties with loss : 0.010784620702051516
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 59
# Computing q and s
# Computing loss table ..., actual mi 4.665188746059216
# Best pair to merge : :, under with loss : 0.011353988090197602
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 58
# Computing q and s
# Computing loss table ..., actual mi 4.653834757969023
# Best pair to merge : for, if with loss : 0.011383322219228068
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 57
# Computing q and s
# Computing loss table ..., actual mi 4.642451435749799
# Best pair to merge : any, their with loss : 0.011691206628487338
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 56
# Computing q and s
# Computing loss table ..., actual mi 4.630760229121318
# Best pair to merge : facts, ) with loss : 0.011894394954275779
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 55
# Computing q and s
# Computing loss table ..., actual mi 4.618865834167043
# Best pair to merge : such, domesticated with loss : 0.011786983113229895
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 54
# Computing q and s
# Computing loss table ..., actual mi 4.6070788510538145
# Best pair to merge : same, many with loss : 0.012663922413863472
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 53
# Computing q and s
# Computing loss table ..., actual mi 4.5944149286399485
# Best pair to merge : will, may with loss : 0.012720341805269868
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 52
# Computing q and s
# Computing loss table ..., actual mi 4.581694586834676
# Best pair to merge : with, by with loss : 0.014083016627558231
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 51
# Computing q and s
# Computing loss table ..., actual mi 4.567611570207116
# Best pair to merge : not, often with loss : 0.014298308862549177
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 50
# Computing q and s
# Computing loss table ..., actual mi 4.552063313964578
# Best pair to merge : subject, structure with loss : 0.015156280484622447
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 49
# Computing q and s
# Computing loss table ..., actual mi 4.536907033479956
# Best pair to merge : I, we with loss : 0.01523241134356846
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 48
# Computing q and s
# Computing loss table ..., actual mi 4.521674622136397
# Best pair to merge : short, more with loss : 0.015316909649152551
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 47
# Computing q and s
# Computing loss table ..., actual mi 4.506357712487241
# Best pair to merge : much, all with loss : 0.016061777328767502
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 46
# Computing q and s
# Computing loss table ..., actual mi 4.490295935158472
# Best pair to merge : certain, several with loss : 0.016533855600104695
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 45
# Computing q and s
# Computing loss table ..., actual mi 4.4737620795583615
# Best pair to merge : has, is with loss : 0.016744824306466635
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 44
# Computing q and s
# Computing loss table ..., actual mi 4.457017255251905
# Best pair to merge : this, which with loss : 0.016745833985852922
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 43
# Computing q and s
# Computing loss table ..., actual mi 4.440271421266056
# Best pair to merge : as, ( with loss : 0.01734952657445777
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 42
# Computing q and s
# Computing loss table ..., actual mi 4.4229218946916005
# Best pair to merge : on, me with loss : 0.01762828488088703
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 41
# Computing q and s
# Computing loss table ..., actual mi 4.405293609810713
# Best pair to merge : facts, species with loss : 0.01829042773074864
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 40
# Computing q and s
# Computing loss table ..., actual mi 4.387003182079971
# Best pair to merge : have, do with loss : 0.018166948617218
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 39
# Computing q and s
# Computing loss table ..., actual mi 4.368836233462758
# Best pair to merge : been, not with loss : 0.018606677862580953
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 38
# Computing q and s
# Computing loss table ..., actual mi 4.348663835191179
# Best pair to merge : some, any with loss : 0.019712331316064903
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 37
# Computing q and s
# Computing loss table ..., actual mi 4.328951503875121
# Best pair to merge : one, same with loss : 0.020153892548036345
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 36
# Computing q and s
# Computing loss table ..., actual mi 4.308797611327088
# Best pair to merge : :, from with loss : 0.021269617173331173
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 35
# Computing q and s
# Computing loss table ..., actual mi 4.287527994153756
# Best pair to merge : I, it with loss : 0.021522208589641982
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 34
# Computing q and s
# Computing loss table ..., actual mi 4.266005785564108
# Best pair to merge : for, or with loss : 0.021837641219238896
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 33
# Computing q and s
# Computing loss table ..., actual mi 4.244168144344851
# Best pair to merge : certain, our with loss : 0.023490613163244377
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 32
# Computing q and s
# Computing loss table ..., actual mi 4.2206775311816
# Best pair to merge : In, are with loss : 0.023946203211567756
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 31
# Computing q and s
# Computing loss table ..., actual mi 4.196731327970049
# Best pair to merge : short, such with loss : 0.0285010828476241
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 30
# Computing q and s
# Computing loss table ..., actual mi 4.168230245122419
# Best pair to merge : facts, subject with loss : 0.028743160405714438
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 29
# Computing q and s
# Computing loss table ..., actual mi 4.139487084716711
# Best pair to merge : has, have with loss : 0.028904427209671707
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 28
# Computing q and s
# Computing loss table ..., actual mi 4.110582657507027
# Best pair to merge : some, a with loss : 0.029237863117324833
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 27
# Computing q and s
# Computing loss table ..., actual mi 4.081344794389699
# Best pair to merge : as, for with loss : 0.02932380713939904
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 26
# Computing q and s
# Computing loss table ..., actual mi 4.051758101353295
# Best pair to merge : much, this with loss : 0.029480566249220137
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 25
# Computing q and s
# Computing loss table ..., actual mi 4.022277535104076
# Best pair to merge : with, that with loss : 0.029414334083038896
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 24
# Computing q and s
# Computing loss table ..., actual mi 3.992863201021046
# Best pair to merge : be, been with loss : 0.033394052292755966
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 23
# Computing q and s
# Computing loss table ..., actual mi 3.9593177517211364
# Best pair to merge : on, : with loss : 0.03444439927397566
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 22
# Computing q and s
# Computing loss table ..., actual mi 3.9248733524471593
# Best pair to merge : will, has with loss : 0.03511052224974129
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 21
# Computing q and s
# Computing loss table ..., actual mi 3.890028772784789
# Best pair to merge : certain, one with loss : 0.03765107835232829
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 20
# Computing q and s
# Computing loss table ..., actual mi 3.8523776944324704
# Best pair to merge : ;, In with loss : 0.03841268110256314
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 19
# Computing q and s
# Computing loss table ..., actual mi 3.8139650133299137
# Best pair to merge : on, in with loss : 0.04821999715215722
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 18
# Computing q and s
# Computing loss table ..., actual mi 3.765745016177774
# Best pair to merge : much, with with loss : 0.050217854398478534
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 17
# Computing q and s
# Computing loss table ..., actual mi 3.7133046620409793
# Best pair to merge : as, and with loss : 0.05214975824289633
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 16
# Computing q and s
# Computing loss table ..., actual mi 3.661538419963275
# Best pair to merge : certain, short with loss : 0.056444488448435096
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 15
# Computing q and s
# Computing loss table ..., actual mi 3.6048223591668553
# Best pair to merge : to, be with loss : 0.06432899999005671
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 14
# Computing q and s
# Computing loss table ..., actual mi 3.539860501432316
# Best pair to merge : the, some with loss : 0.06738929597266213
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 13
# Computing q and s
# Computing loss table ..., actual mi 3.472471205459653
# Best pair to merge : I, ; with loss : 0.07694548696046927
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 12
# Computing q and s
# Computing loss table ..., actual mi 3.3954407093163
# Best pair to merge : on, of with loss : 0.09277940334117443
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 11
# Computing q and s
# Computing loss table ..., actual mi 3.302661305975112
# Best pair to merge : certain, facts with loss : 0.08948582519492415
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 10
# Computing q and s
# Computing loss table ..., actual mi 3.1979704641743436
# Best pair to merge : as, will with loss : 0.10365804022927722
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 9
# Computing q and s
# Computing loss table ..., actual mi 3.0970938946219726
# Best pair to merge : much, to with loss : 0.10192215352390169
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 8
# Computing q and s
# Computing loss table ..., actual mi 2.996281039383386
# Best pair to merge : ,, I with loss : 0.1156579665347563
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 7
# Computing q and s
# Computing loss table ..., actual mi 2.8825026884688842
# Best pair to merge : ., certain with loss : 0.13577731314463148
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 6
# Computing q and s
# Computing loss table ..., actual mi 2.750993562027393
# Best pair to merge : on, much with loss : 0.19191511125574878
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 5
# Computing q and s
# Computing loss table ..., actual mi 2.5650327860495827
# Best pair to merge : as, , with loss : 0.2105795333645443
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 4
# Computing q and s
# Computing loss table ..., actual mi 2.335269444763917
# Best pair to merge : ., the with loss : 0.23691592730032365
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 3
# Computing q and s
# Computing loss table ..., actual mi 2.11423521643416
# Best pair to merge : on, as with loss : 0.3498247939295359
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 2
# Computing q and s
# Computing loss table ..., actual mi 1.79356788327674
# Best pair to merge : on, . with loss : 0.5085870864644936
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 1

# %%
# perform clusterin on czech data
browns_clustering(wordsCZ[:8000], 'CZ', 10)
# Out:
# Computing q and s
# Computing loss table ..., actual mi 7.557964220781474
# Best pair to merge : listopadu, OKD with loss : 0.0030832696793098354
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.554880951102163
# Best pair to merge : který, které with loss : 0.0033738533738386783
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.551507097728323
# Best pair to merge : J, státu with loss : 0.004025469551221374
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.5474816281771
# Best pair to merge : bude, musí with loss : 0.004422152935165135
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.54305947524194
# Best pair to merge : aby, ale with loss : 0.004604358224104727
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.5384551170178336
# Best pair to merge : nás, bylo with loss : 0.00464762929700922
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.533807487720826
# Best pair to merge : pouze, si with loss : 0.004992033285278183
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.528815454435553
# Best pair to merge : mezi, už with loss : 0.005000625078134785
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.523814829357424
# Best pair to merge : NATO, &slash; with loss : 0.005561973371130537
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.5182528559862964
# Best pair to merge : jeho, ze with loss : 0.005564965527577216
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.512687890458715
# Best pair to merge : být, však with loss : 0.0057435025377872324
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.506944387920929
# Best pair to merge : byl, jsou with loss : 0.0057507188398549895
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.501193669081071
# Best pair to merge : ?, před with loss : 0.00600075009376173
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.495192918987307
# Best pair to merge : budou, jako with loss : 0.006250781347668471
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.488942137639643
# Best pair to merge : Na, listopadu with loss : 0.006392241353892936
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.482549896285742
# Best pair to merge : zákona, při with loss : 0.006900281851402325
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.475649614434328
# Best pair to merge : za, u with loss : 0.007556757128493526
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.468092857305828
# Best pair to merge : J, ČSFR with loss : 0.007604054493371527
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.46048880281247
# Best pair to merge : který, aby with loss : 0.007741722351558053
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.452747080460918
# Best pair to merge : včera, nás with loss : 0.007768675181722449
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.444978405279186
# Best pair to merge : od, mezi with loss : 0.00879081857063873
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.436187586708552
# Best pair to merge : bude, být with loss : 0.010211489857351461
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.425976096851193
# Best pair to merge : byl, pouze with loss : 0.010215182757638143
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.415760914093556
# Best pair to merge : po, pro with loss : 0.01025128141017629
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.405509632683374
# Best pair to merge : V, Na with loss : 0.010521638598616621
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.394987994084748
# Best pair to merge : jeho, to with loss : 0.011671664260760151
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.383316329823991
# Best pair to merge : ve, NATO with loss : 0.011812754718798928
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.37150357510519
# Best pair to merge : budou, ? with loss : 0.012487130091201455
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.3590164450139826
# Best pair to merge : který, že with loss : 0.01312530920096825
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.345891135813011
# Best pair to merge : k, zákona with loss : 0.013300457497882681
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.332590678315141
# Best pair to merge : včera, by with loss : 0.014888859032793612
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.317701819282344
# Best pair to merge : do, za with loss : 0.01590994992893225
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.301791869353397
# Best pair to merge : ), J with loss : 0.016598384072694913
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.28519348528068
# Best pair to merge : i, je with loss : 0.016814436086526656
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.268379049194149
# Best pair to merge : :, po with loss : 0.018074583700848294
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.250304465493316
# Best pair to merge : od, z with loss : 0.019892422537302445
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.231010817677556
# Best pair to merge : (, byl with loss : 0.02123519941582614
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.209775618261708
# Best pair to merge : bude, budou with loss : 0.02298085938959757
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.1882231505376515
# Best pair to merge : jeho, ve with loss : 0.023759901792583117
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.164854478773914
# Best pair to merge : V, s with loss : 0.025143854087541495
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.1397106246863515
# Best pair to merge : k, do with loss : 0.028613679162343225
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.111096945524064
# Best pair to merge : včera, i with loss : 0.02825800947593418
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.082838936048149
# Best pair to merge : ), " with loss : 0.031524245317785235
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.051300554659981
# Best pair to merge : :, - with loss : 0.033813428952435595
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 7.017487125707507
# Best pair to merge : jeho, od with loss : 0.03869043602897847
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 6.97834241394301
# Best pair to merge : o, bude with loss : 0.043360876930009826
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 6.935994719225461
# Best pair to merge : (, se with loss : 0.04534581208102903
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 6.890648907144401
# Best pair to merge : včera, který with loss : 0.04947815214279312
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 6.840783413646752
# Best pair to merge : V, ) with loss : 0.05082052349681711
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 6.789675818655029
# Best pair to merge : k, na with loss : 0.055441937089344334
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 6.734233881565704
# Best pair to merge : :, jeho with loss : 0.06955051097654977
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 6.663656629855331
# Best pair to merge : o, v with loss : 0.07503358487880307
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 6.588215577181089
# Best pair to merge : (, a with loss : 0.08386732290837651
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 6.504545082052943
# Best pair to merge : V, k with loss : 0.10994702962303463
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 6.394871717406796
# Best pair to merge : :, včera with loss : 0.11620865799123953
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 6.279836145060853
# Best pair to merge : (, o with loss : 0.15083562063243228
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 6.1275562013773435
# Best pair to merge : :, , with loss : 0.1840172554496357
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 5.922406710777925
# Best pair to merge : V, . with loss : 0.20622668460876087
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 5.703529167225262
# Best pair to merge : :, ( with loss : 0.28027472002759213
# ----------------------------------------------------------------------------------------------------
#
# Computing q and s
# Computing loss table ..., actual mi 5.414197957205444
# Best pair to merge : V, : with loss : 0.4063113851929383
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #3) Tags clustering

# %%
# perform clustering for ENG tags
browns_clustering(tagsEN,name = 'tagsEN', limit= 5)
# Out:
# Computing q and s
# Computing loss table ..., actual mi 0.8833168327193148
# Best pair to merge : RBR, WP$ with loss : 0.0002189398918106662
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 35
# Computing q and s
# Computing loss table ..., actual mi 0.8830978928275041
# Best pair to merge : JJR, RBR with loss : 0.00034888337197445853
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 34
# Computing q and s
# Computing loss table ..., actual mi 0.8827490094555294
# Best pair to merge : SYM, NNPS with loss : 0.0008193622508581421
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 33
# Computing q and s
# Computing loss table ..., actual mi 0.881929647204671
# Best pair to merge : PRP, EX with loss : 0.0010847100426949925
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 32
# Computing q and s
# Computing loss table ..., actual mi 0.8808449371619764
# Best pair to merge : NNP, FW with loss : 0.0012185934086710992
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 31
# Computing q and s
# Computing loss table ..., actual mi 0.878553959137846
# Best pair to merge : ., ( with loss : 0.0013169373706564472
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 30
# Computing q and s
# Computing loss table ..., actual mi 0.8772370217671895
# Best pair to merge : WP, " with loss : 0.0013896680065684532
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 29
# Computing q and s
# Computing loss table ..., actual mi 0.8758410240462954
# Best pair to merge : JJ, JJS with loss : 0.0017369103238663516
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 28
# Computing q and s
# Computing loss table ..., actual mi 0.8739690291291202
# Best pair to merge : JJR, RBS with loss : 0.0021076059079176536
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 27
# Computing q and s
# Computing loss table ..., actual mi 0.8718614232212025
# Best pair to merge : WRB, WP with loss : 0.0023036866757933675
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 26
# Computing q and s
# Computing loss table ..., actual mi 0.8695693229885524
# Best pair to merge : DT, PRP$ with loss : 0.002653910690184405
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 25
# Computing q and s
# Computing loss table ..., actual mi 0.866915412298368
# Best pair to merge : JJ, CD with loss : 0.003314036042230878
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 24
# Computing q and s
# Computing loss table ..., actual mi 0.8626765004663121
# Best pair to merge : NNP, SYM with loss : 0.0036548691821135515
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 23
# Computing q and s
# Computing loss table ..., actual mi 0.8567733608642812
# Best pair to merge : WRB, WDT with loss : 0.005996507807613733
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 22
# Computing q and s
# Computing loss table ..., actual mi 0.8508251597867535
# Best pair to merge : ,, : with loss : 0.005947107169658766
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 21
# Computing q and s
# Computing loss table ..., actual mi 0.8448780526170951
# Best pair to merge : VBD, VBN with loss : 0.006199338355648794
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 20
# Computing q and s
# Computing loss table ..., actual mi 0.8332590330682762
# Best pair to merge : VBZ, VBP with loss : 0.006975469936434026
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 19
# Computing q and s
# Computing loss table ..., actual mi 0.8264731122456025
# Best pair to merge : VBG, JJR with loss : 0.008917516656470946
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 18
# Computing q and s
# Computing loss table ..., actual mi 0.8176584310216792
# Best pair to merge : NN, NNS with loss : 0.00906587770640327
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 17
# Computing q and s
# Computing loss table ..., actual mi 0.813130889497833
# Best pair to merge : WRB, PRP with loss : 0.014132053133133385
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 16
# Computing q and s
# Computing loss table ..., actual mi 0.7974563322092542
# Best pair to merge : ., , with loss : 0.014757307737649245
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 15
# Computing q and s
# Computing loss table ..., actual mi 0.7841076709537209
# Best pair to merge : JJ, VBG with loss : 0.019503032994618176
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 14
# Computing q and s
# Computing loss table ..., actual mi 0.7624641076364066
# Best pair to merge : MD, VBZ with loss : 0.027240935006958344
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 13
# Computing q and s
# Computing loss table ..., actual mi 0.7356099799842991
# Best pair to merge : VB, RB with loss : 0.02731338323965772
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 12
# Computing q and s
# Computing loss table ..., actual mi 0.695520157500471
# Best pair to merge : IN, TO with loss : 0.02005636273872445
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 11
# Computing q and s
# Computing loss table ..., actual mi 0.6759522932568653
# Best pair to merge : WRB, NNP with loss : 0.029533841911926158
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 10
# Computing q and s
# Computing loss table ..., actual mi 0.6459972358637774
# Best pair to merge : VBD, VB with loss : 0.037106882629023626
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 9
# Computing q and s
# Computing loss table ..., actual mi 0.5893361450908841
# Best pair to merge : IN, CC with loss : 0.037858232592588206
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 8
# Computing q and s
# Computing loss table ..., actual mi 0.5573117865370045
# Best pair to merge : ., MD with loss : 0.06971553977795295
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 7
# Computing q and s
# Computing loss table ..., actual mi 0.5007358879651771
# Best pair to merge : WRB, VBD with loss : 0.038620902189210826
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 6
# Computing q and s
# Computing loss table ..., actual mi 0.46843716806556085
# Best pair to merge : JJ, DT with loss : 0.08869781689123696
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 5
# Computing q and s
# Computing loss table ..., actual mi 0.36351817830225963
# Best pair to merge : IN, . with loss : 0.12958687540573455
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 4
# Computing q and s
# Computing loss table ..., actual mi 0.2775821443060458
# Best pair to merge : WRB, JJ with loss : 0.11367548377229936
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 3
# Computing q and s
# Computing loss table ..., actual mi 0.1959309044453449
# Best pair to merge : WRB, NN with loss : 0.24862315472618063
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 2
# Computing q and s
# Computing loss table ..., actual mi -0.06090868823536749
# Best pair to merge : WRB, IN with loss : 0.2590001274757964
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 1

# %%
# perform clustering for 70 000 CZ tags
browns_clustering(tagsCZ[:70000], name = 'tagsCZ', limit= 5)
# Out:
# Computing q and s
# Computing loss table ..., actual mi 1.7993522739317134
# Best pair to merge : CrFS6----------, PSFS6-P1------- with loss : 4.2807217565245725e-05
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 454
# Computing q and s
# Computing loss table ..., actual mi 1.7993094667141478
# Best pair to merge : PZXP6----------, Ca--6---------- with loss : 6.143881513639483e-05
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 453
# Computing q and s
# Computing loss table ..., actual mi 1.7992480278990113
# Best pair to merge : PSZS6FS3-------, PSZS6-P1------- with loss : 7.104686862486416e-05
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 452
# Computing q and s
# Computing loss table ..., actual mi 1.7991769810303866
# Best pair to merge : AUFS6M---------, CrFS6---------- with loss : 7.777430212249962e-05
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 451
# Computing q and s
# Computing loss table ..., actual mi 1.7990992067282645
# Best pair to merge : P6-X6----------, P5FS6--3------- with loss : 8.087692070404742e-05
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 450
# Computing q and s
# Computing loss table ..., actual mi 1.7990183298075604
# Best pair to merge : J^------------8, PP-P1--2------- with loss : 8.415880476883683e-05
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 449
# Computing q and s
# Computing loss table ..., actual mi 1.7989341710027913
# Best pair to merge : PSYS1-P1-------, PZYS1---------- with loss : 9.314972695721415e-05
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 448
# Computing q and s
# Computing loss table ..., actual mi 1.7988410212758346
# Best pair to merge : P4XP3----------, PJXP1---------- with loss : 9.512473694785016e-05
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 447
# Computing q and s
# Computing loss table ..., actual mi 1.7987458965388865
# Best pair to merge : P5XP6--3-------, NNMP6-----A---- with loss : 9.645302818503529e-05
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 446
# Computing q and s
# Computing loss table ..., actual mi 1.798649443510701
# Best pair to merge : PSHS1-P1-------, PSHS1-S1------- with loss : 0.00010571050948696798
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 445
# Computing q and s
# Computing loss table ..., actual mi 1.798543733001214
# Best pair to merge : AGFS6-----A----, P8FS6---------1 with loss : 0.0001078890157014574
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 444
# Computing q and s
# Computing loss table ..., actual mi 1.7984358439855124
# Best pair to merge : PZFS4----------, AUFS4M--------- with loss : 0.00010863015394509405
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 443
# Computing q and s
# Computing loss table ..., actual mi 1.7983272138315676
# Best pair to merge : Cn-P6----------, PSXP6-P1------- with loss : 0.00011018681224429501
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 442
# Computing q and s
# Computing loss table ..., actual mi 1.798217027019323
# Best pair to merge : ClFS6----------, PDFS6---------- with loss : 0.00011489166225247399
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 441
# Computing q and s
# Computing loss table ..., actual mi 1.7981021353570705
# Best pair to merge : AAIP1----3A----, CrIP1---------- with loss : 0.00011702093814378609
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 440
# Computing q and s
# Computing loss table ..., actual mi 1.797985114418927
# Best pair to merge : AGIS7-----A----, ClNS1---------- with loss : 0.00011798774522573508
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 439
# Computing q and s
# Computing loss table ..., actual mi 1.7978671266737014
# Best pair to merge : PDFS7----------, AGFS7-----A---- with loss : 0.00011936728668834591
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 438
# Computing q and s
# Computing loss table ..., actual mi 1.7977477593870126
# Best pair to merge : PJYS1----------, PJNS1---------- with loss : 0.00012234830378748322
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 437
# Computing q and s
# Computing loss table ..., actual mi 1.7976254110832246
# Best pair to merge : PJZS3----------, P4YP4---------- with loss : 0.00012260914917900452
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 436
# Computing q and s
# Computing loss table ..., actual mi 1.797502801934046
# Best pair to merge : PZIS4----------, ClIS4---------- with loss : 0.00013031606683308193
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 435
# Computing q and s
# Computing loss table ..., actual mi 1.7973724858672124
# Best pair to merge : AUIS2M---------, AAIS2----1N---- with loss : 0.0001312308836318994
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 434
# Computing q and s
# Computing loss table ..., actual mi 1.7972412549835808
# Best pair to merge : PZFS4----------, PWFS4---------- with loss : 0.00013468922332132293
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 433
# Computing q and s
# Computing loss table ..., actual mi 1.7971065657602596
# Best pair to merge : AANS1----2A----, AANS1----1N---- with loss : 0.00013481573374901396
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 432
# Computing q and s
# Computing loss table ..., actual mi 1.7969717500265106
# Best pair to merge : PSZS6FS3-------, CrNS6---------- with loss : 0.00014009903757441372
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 431
# Computing q and s
# Computing loss table ..., actual mi 1.7968316509889357
# Best pair to merge : AAIS7----1N----, CrIS7---------- with loss : 0.00014098293764900987
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 430
# Computing q and s
# Computing loss table ..., actual mi 1.7966906680512862
# Best pair to merge : AAFS4----2A----, P8FS4---------- with loss : 0.00014110032806772047
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 429
# Computing q and s
# Computing loss table ..., actual mi 1.7965495677232182
# Best pair to merge : P5ZS3--3-------, PDFS3---------- with loss : 0.00014285918370262468
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 428
# Computing q and s
# Computing loss table ..., actual mi 1.7964067085395152
# Best pair to merge : AAMS1----1N----, AUMS1M--------- with loss : 0.0001462487209907471
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 427
# Computing q and s
# Computing loss table ..., actual mi 1.7962604598185246
# Best pair to merge : II-------------, AAIS1----1A---6 with loss : 0.00014707761126265758
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 426
# Computing q and s
# Computing loss table ..., actual mi 1.796113382207262
# Best pair to merge : PSXP2-P1-------, P4XP2---------- with loss : 0.00014798625192025724
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 425
# Computing q and s
# Computing loss table ..., actual mi 1.7959653959553419
# Best pair to merge : AGFP1-----A----, PZFP1---------- with loss : 0.00014827552893442947
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 424
# Computing q and s
# Computing loss table ..., actual mi 1.7958171204264077
# Best pair to merge : P5ZS7--3-------, P9ZS7---------- with loss : 0.00014994608296400522
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 423
# Computing q and s
# Computing loss table ..., actual mi 1.7956671743434438
# Best pair to merge : P4FS1----------, PE--1---------- with loss : 0.00015182115837691738
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 422
# Computing q and s
# Computing loss table ..., actual mi 1.7955153531850672
# Best pair to merge : VB-P---1F-AA---, VB-S---1P-NA--1 with loss : 0.00015417934955481972
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 421
# Computing q and s
# Computing loss table ..., actual mi 1.7953611738355117
# Best pair to merge : AAIS6----1A----, AUIS6M--------- with loss : 0.00015443345457456792
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 420
# Computing q and s
# Computing loss table ..., actual mi 1.7952067403809377
# Best pair to merge : AAIS1----2A----, Dg-------1A---1 with loss : 0.00015752546699173732
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 419
# Computing q and s
# Computing loss table ..., actual mi 1.7950492149139456
# Best pair to merge : PDXP6----------, PZXP6---------- with loss : 0.00015996453000597277
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 418
# Computing q and s
# Computing loss table ..., actual mi 1.7948892503839406
# Best pair to merge : CrFS2----------, AUFS2M--------- with loss : 0.0001606169772532766
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 417
# Computing q and s
# Computing loss table ..., actual mi 1.7947286334066874
# Best pair to merge : PSMP1-P1-------, PZMP1---------- with loss : 0.00017031150282448293
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 416
# Computing q and s
# Computing loss table ..., actual mi 1.794558321903863
# Best pair to merge : PP-P7--1-------, P5XP7--3------- with loss : 0.00017034577047025544
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 415
# Computing q and s
# Computing loss table ..., actual mi 1.7943879761333927
# Best pair to merge : PSXP4-P1-------, PDMP4---------- with loss : 0.00017143102044314912
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 414
# Computing q and s
# Computing loss table ..., actual mi 1.79421654511295
# Best pair to merge : C?--4----------, J,-P---1------- with loss : 0.00017601847540304376
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 413
# Computing q and s
# Computing loss table ..., actual mi 1.7940405266375465
# Best pair to merge : P8YP4---------1, PZYP4---------- with loss : 0.00017803552535930077
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 412
# Computing q and s
# Computing loss table ..., actual mi 1.7938624911121872
# Best pair to merge : AUFS6M---------, ClFS6---------- with loss : 0.0001781624818463297
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 411
# Computing q and s
# Computing loss table ..., actual mi 1.793684328630341
# Best pair to merge : PSZS1FS3-------, AUNS1M--------- with loss : 0.000180230032068256
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 410
# Computing q and s
# Computing loss table ..., actual mi 1.7935040985982729
# Best pair to merge : P8FP4---------1, PLFP4---------- with loss : 0.00018055985944156474
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 409
# Computing q and s
# Computing loss table ..., actual mi 1.7933235387388313
# Best pair to merge : PSZS2-P1-------, PSZS2FS3------- with loss : 0.0001813471913793246
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 408
# Computing q and s
# Computing loss table ..., actual mi 1.7931421915474521
# Best pair to merge : PLFP1----------, AAFP1----3A---- with loss : 0.00018271198626879158
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 407
# Computing q and s
# Computing loss table ..., actual mi 1.7929594795611838
# Best pair to merge : A2--------A----, J^------------8 with loss : 0.00018343218248870901
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 406
# Computing q and s
# Computing loss table ..., actual mi 1.7927760473786953
# Best pair to merge : P9XP2----------, P5ZS2--3------- with loss : 0.0001850294215592302
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 405
# Computing q and s
# Computing loss table ..., actual mi 1.7925910179571363
# Best pair to merge : PWYS1----------, AUIS1M--------- with loss : 0.0001862049569555951
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 404
# Computing q and s
# Computing loss table ..., actual mi 1.7924048130001806
# Best pair to merge : PDXP7----------, P6-X7---------- with loss : 0.00018897960404791404
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 403
# Computing q and s
# Computing loss table ..., actual mi 1.792215833396133
# Best pair to merge : ClZS2----------, ClZS3---------- with loss : 0.00018921859594903535
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 402
# Computing q and s
# Computing loss table ..., actual mi 1.7920266148001842
# Best pair to merge : P5ZS4--3-------, P5XP4--3------- with loss : 0.0001922565791674239
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 401
# Computing q and s
# Computing loss table ..., actual mi 1.7918343582210166
# Best pair to merge : Cn-P7----------, P8XP7---------- with loss : 0.00019330669524775766
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 400
# Computing q and s
# Computing loss table ..., actual mi 1.7916410515257686
# Best pair to merge : P5XP2--3-------, P6-X2---------- with loss : 0.00019883852565939623
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 399
# Computing q and s
# Computing loss table ..., actual mi 1.7914422130001095
# Best pair to merge : Dg-------3A---1, Co------------- with loss : 0.00020000285718367388
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 398
# Computing q and s
# Computing loss table ..., actual mi 1.7912422101429255
# Best pair to merge : AAFS1----3A----, NNFS1-----A---1 with loss : 0.00020124514304820334
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 397
# Computing q and s
# Computing loss table ..., actual mi 1.7910409649998773
# Best pair to merge : CrFS4----------, VB-P---2P-NA--- with loss : 0.00020700617145492136
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 396
# Computing q and s
# Computing loss table ..., actual mi 1.7908339588284226
# Best pair to merge : AAMS4----1A----, ClMS4---------- with loss : 0.00020766027215885874
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 395
# Computing q and s
# Computing loss table ..., actual mi 1.7906262985562638
# Best pair to merge : AGIP2-----A----, AANS2----1N---- with loss : 0.00020891087236469825
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 394
# Computing q and s
# Computing loss table ..., actual mi 1.7904173876838996
# Best pair to merge : ClXP6----------, P8XP6---------- with loss : 0.00021079398931313437
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 393
# Computing q and s
# Computing loss table ..., actual mi 1.7902065936945872
# Best pair to merge : PJZS3----------, P4NS4---------- with loss : 0.0002109916589025405
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 392
# Computing q and s
# Computing loss table ..., actual mi 1.7899956020356842
# Best pair to merge : PZIS4----------, AGIS4-----A---- with loss : 0.0002129071201417798
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 391
# Computing q and s
# Computing loss table ..., actual mi 1.7897826949155424
# Best pair to merge : AAIP1----3A----, AAIP1----1N---- with loss : 0.00021920209925593024
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 390
# Computing q and s
# Computing loss table ..., actual mi 1.7895634928162862
# Best pair to merge : P8ZS2----------, PSZS2-S1------- with loss : 0.00022507429719608005
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 389
# Computing q and s
# Computing loss table ..., actual mi 1.7893384185190901
# Best pair to merge : NNMS6-----A---1, NNFP1-----N---- with loss : 0.00022565155048683916
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 388
# Computing q and s
# Computing loss table ..., actual mi 1.7891127669686027
# Best pair to merge : AANP7----1A----, AGMS1-----A---- with loss : 0.00022669844787058448
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 387
# Computing q and s
# Computing loss table ..., actual mi 1.7888860685207322
# Best pair to merge : AAMP2----1N----, PLFS1---------- with loss : 0.00022867576901528224
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 386
# Computing q and s
# Computing loss table ..., actual mi 1.788657392751717
# Best pair to merge : PPZS7--3-------, PPNS4--3------- with loss : 0.0002322750921878345
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 385
# Computing q and s
# Computing loss table ..., actual mi 1.7884251176595294
# Best pair to merge : CrIS1----------, PSYS1-P1------- with loss : 0.00023549632624292837
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 384
# Computing q and s
# Computing loss table ..., actual mi 1.788189621333286
# Best pair to merge : Vf--------A---1, AAMP1----1N---- with loss : 0.00023673436753306795
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 383
# Computing q and s
# Computing loss table ..., actual mi 1.7879528869657526
# Best pair to merge : VB-P---3P-NA--1, VB-P---3F-NA--- with loss : 0.0002397482992890789
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 382
# Computing q and s
# Computing loss table ..., actual mi 1.7877131386664635
# Best pair to merge : P5ZS6--3-------, P6-X6---------- with loss : 0.00024045343943192884
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 381
# Computing q and s
# Computing loss table ..., actual mi 1.7874726852270313
# Best pair to merge : PSFS2-P1-------, AGFS2-----A---- with loss : 0.00024184562597456924
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 380
# Computing q and s
# Computing loss table ..., actual mi 1.787230839601057
# Best pair to merge : II-------------, NNIS2-----A---1 with loss : 0.00024188526391077068
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 379
# Computing q and s
# Computing loss table ..., actual mi 1.786988954337146
# Best pair to merge : AAIS1----2A----, AAIS1----1N---- with loss : 0.00024418003365383567
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 378
# Computing q and s
# Computing loss table ..., actual mi 1.7867447743034923
# Best pair to merge : P4ZS6----------, AGFS6-----A---- with loss : 0.00025030170674837865
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 377
# Computing q and s
# Computing loss table ..., actual mi 1.7864944725967433
# Best pair to merge : NNFS5-----A----, AAMS6----1A---- with loss : 0.00025312659180021127
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 376
# Computing q and s
# Computing loss table ..., actual mi 1.7862413460049429
# Best pair to merge : AANP1----1A----, CrNP1---------- with loss : 0.0002570057587565442
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 375
# Computing q and s
# Computing loss table ..., actual mi 1.7859843402461868
# Best pair to merge : Cn-P6----------, PDXP6---------- with loss : 0.00025742512675495585
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 374
# Computing q and s
# Computing loss table ..., actual mi 1.785726915119432
# Best pair to merge : P5FS4--3-------, P6-X4---------- with loss : 0.0002591833685663537
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 373
# Computing q and s
# Computing loss table ..., actual mi 1.785467731750865
# Best pair to merge : ClXP7----------, Cn-P7---------- with loss : 0.00026036162854791225
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 372
# Computing q and s
# Computing loss table ..., actual mi 1.7852073701223177
# Best pair to merge : AGIS2-----A----, NNFS4-----N---- with loss : 0.0002608469289283595
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 371
# Computing q and s
# Computing loss table ..., actual mi 1.7849465231933892
# Best pair to merge : J^------------1, AGFP2-----A---- with loss : 0.0002611362059425314
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 370
# Computing q and s
# Computing loss table ..., actual mi 1.784685386987447
# Best pair to merge : PSFS4-P1-------, PZFS4---------- with loss : 0.0002620368744134761
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 369
# Computing q and s
# Computing loss table ..., actual mi 1.7844233501130335
# Best pair to merge : Vi-P---1--A----, Vi-S---2--A---- with loss : 0.00026205517741687424
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 368
# Computing q and s
# Computing loss table ..., actual mi 1.7841612949356171
# Best pair to merge : AAFP2----1N----, AAFP2----2A---- with loss : 0.00026327703802231264
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 367
# Computing q and s
# Computing loss table ..., actual mi 1.7838980178975952
# Best pair to merge : P4XP3----------, C?--4---------- with loss : 0.00026608080802970036
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 366
# Computing q and s
# Computing loss table ..., actual mi 1.7836319370895657
# Best pair to merge : P8FS2---------1, AAFS2----1N---- with loss : 0.0002664228515410084
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 365
# Computing q and s
# Computing loss table ..., actual mi 1.783365514238025
# Best pair to merge : PP-P2--1-------, P5XP2--3------- with loss : 0.0002664404260228938
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 364
# Computing q and s
# Computing loss table ..., actual mi 1.7830990738120023
# Best pair to merge : PSXP2-P1-------, Ca--2---------- with loss : 0.00026754860737581766
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 363
# Computing q and s
# Computing loss table ..., actual mi 1.7828315252046265
# Best pair to merge : ClZS7----------, AGIS7-----A---- with loss : 0.0002718541626270393
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 362
# Computing q and s
# Computing loss table ..., actual mi 1.7825596710419995
# Best pair to merge : AAFS1----1N----, AAFS1----2A---- with loss : 0.00027734656321624224
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 361
# Computing q and s
# Computing loss table ..., actual mi 1.7822823244787833
# Best pair to merge : PSZS6FS3-------, P8ZS6---------- with loss : 0.00027832431580853637
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 360
# Computing q and s
# Computing loss table ..., actual mi 1.7820040001629744
# Best pair to merge : AAFP4----1A----, PZFP4---------- with loss : 0.0002783540660615648
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 359
# Computing q and s
# Computing loss table ..., actual mi 1.7817256460969135
# Best pair to merge : P8FS7---------1, PDFS7---------- with loss : 0.00028096331266161075
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 358
# Computing q and s
# Computing loss table ..., actual mi 1.7814446827842518
# Best pair to merge : VpNS---XR-AA--1, P8ZS3---------- with loss : 0.00028413139836580613
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 357
# Computing q and s
# Computing loss table ..., actual mi 1.7811605513858855
# Best pair to merge : PDIP1----------, AGIP1-----A---- with loss : 0.00028751406475910715
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 356
# Computing q and s
# Computing loss table ..., actual mi 1.7808730373211268
# Best pair to merge : AGNS1-----A----, Vf--------N---- with loss : 0.0002927501365326584
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 355
# Computing q and s
# Computing loss table ..., actual mi 1.7805802871845935
# Best pair to merge : PJYS2----------, AGMP1-----A---- with loss : 0.0002963130763842147
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 354
# Computing q and s
# Computing loss table ..., actual mi 1.7802839741082095
# Best pair to merge : PLXP7----------, P8ZS7---------- with loss : 0.0002970852597577989
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 353
# Computing q and s
# Computing loss table ..., actual mi 1.7799868888484518
# Best pair to merge : AANS4----1N----, P8NS4---------1 with loss : 0.0003020299958191007
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 352
# Computing q and s
# Computing loss table ..., actual mi 1.7796848588526328
# Best pair to merge : PSHP1-P1-------, RR--1---------- with loss : 0.0003083813741476168
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 351
# Computing q and s
# Computing loss table ..., actual mi 1.7793764774784857
# Best pair to merge : PJYS1----------, PPYS1--3------- with loss : 0.0003091624207156972
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 350
# Computing q and s
# Computing loss table ..., actual mi 1.77906731505777
# Best pair to merge : P4NS1----------, P4IS4---------- with loss : 0.00031554023224968997
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 349
# Computing q and s
# Computing loss table ..., actual mi 1.7787517748255202
# Best pair to merge : AGFP1-----A----, RF------------- with loss : 0.00031574161468277584
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 348
# Computing q and s
# Computing loss table ..., actual mi 1.7784360332108369
# Best pair to merge : Dg-------3A---1, ACMP------A---- with loss : 0.0003159824681009517
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 347
# Computing q and s
# Computing loss table ..., actual mi 1.7781200507427368
# Best pair to merge : PWYS1----------, AAIS1----3A---- with loss : 0.00032130561391999625
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 346
# Computing q and s
# Computing loss table ..., actual mi 1.777798745128816
# Best pair to merge : AANS1----3A----, PP-P1--1------- with loss : 0.00032188341678781023
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 345
# Computing q and s
# Computing loss table ..., actual mi 1.777476861712029
# Best pair to merge : P4FP1----------, P4IP1---------- with loss : 0.00032468348431494024
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 344
# Computing q and s
# Computing loss table ..., actual mi 1.7771521782277142
# Best pair to merge : AUIS2M---------, CrIS2---------- with loss : 0.00032851592633002
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 343
# Computing q and s
# Computing loss table ..., actual mi 1.776823662301384
# Best pair to merge : CrFS1----------, AAFS1----3A---- with loss : 0.0003288050105097959
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 342
# Computing q and s
# Computing loss table ..., actual mi 1.7764948572908745
# Best pair to merge : PLXP3----------, PDXP3---------- with loss : 0.0003291541778163412
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 341
# Computing q and s
# Computing loss table ..., actual mi 1.7761657031130573
# Best pair to merge : Vi-P---2--A----, VB-P---1F-AA--- with loss : 0.00033437253990412075
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 340
# Computing q and s
# Computing loss table ..., actual mi 1.7758313305731535
# Best pair to merge : AAIS7----1A----, AAIS7----1N---- with loss : 0.0003368008786341888
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 339
# Computing q and s
# Computing loss table ..., actual mi 1.7754945296945204
# Best pair to merge : AANP7----1A----, AAMS1----1N---- with loss : 0.00033776759456296786
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 338
# Computing q and s
# Computing loss table ..., actual mi 1.7751567620999575
# Best pair to merge : PP-S4--1-------, PH-S4--1------- with loss : 0.00033809928345333114
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 337
# Computing q and s
# Computing loss table ..., actual mi 1.7748186628165037
# Best pair to merge : P1XXXZS3-------, PSFSXFS3------- with loss : 0.000340192849015866
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 336
# Computing q and s
# Computing loss table ..., actual mi 1.7744784699674883
# Best pair to merge : AAFS4----2A----, AAFS4----1N---- with loss : 0.00034711528614081986
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 335
# Computing q and s
# Computing loss table ..., actual mi 1.7741313546813469
# Best pair to merge : A2--------A----, AAXXX----1A---8 with loss : 0.00034936513511562683
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 334
# Computing q and s
# Computing loss table ..., actual mi 1.773781989546231
# Best pair to merge : PPXP2--3-------, PPFS3--3------- with loss : 0.0003510530332104221
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 333
# Computing q and s
# Computing loss table ..., actual mi 1.773430936513021
# Best pair to merge : PLNS1----------, PLNS1---------1 with loss : 0.0003516395181450637
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 332
# Computing q and s
# Computing loss table ..., actual mi 1.7730792969948763
# Best pair to merge : PW--4----------, PW--1---------- with loss : 0.00035546210654422805
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 331
# Computing q and s
# Computing loss table ..., actual mi 1.7727238348883325
# Best pair to merge : NNIXX-----A---8, NNMXX-----A---8 with loss : 0.0003660299556082988
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 330
# Computing q and s
# Computing loss table ..., actual mi 1.772357804932724
# Best pair to merge : ClHP1----------, AAFP1----1N---- with loss : 0.000367044911362449
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 329
# Computing q and s
# Computing loss table ..., actual mi 1.7719907600213611
# Best pair to merge : P5ZS7--3-------, PP-P7--1------- with loss : 0.0003707424757107671
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 328
# Computing q and s
# Computing loss table ..., actual mi 1.7716200175456502
# Best pair to merge : ClXP4----------, PSXP4-P1------- with loss : 0.00037147624234947765
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 327
# Computing q and s
# Computing loss table ..., actual mi 1.7712485413033012
# Best pair to merge : PP-P3--2-------, ClFS7---------- with loss : 0.0003756492260338399
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 326
# Computing q and s
# Computing loss table ..., actual mi 1.7708728920772676
# Best pair to merge : ClFS4----------, PSFS4-P1------- with loss : 0.0003775310859665121
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 325
# Computing q and s
# Computing loss table ..., actual mi 1.770495360991301
# Best pair to merge : P5ZS6--3-------, P5XP6--3------- with loss : 0.0003797087322711186
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 324
# Computing q and s
# Computing loss table ..., actual mi 1.7701156522590307
# Best pair to merge : ClFS1----------, AUFS1M--------- with loss : 0.0003902790956868455
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 323
# Computing q and s
# Computing loss table ..., actual mi 1.7697253731633438
# Best pair to merge : ACYS------A----, PZ--4---------- with loss : 0.00039540013847725935
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 322
# Computing q and s
# Computing loss table ..., actual mi 1.7693299730248666
# Best pair to merge : P4FS4----------, PJZS3---------- with loss : 0.00039619761661860474
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 321
# Computing q and s
# Computing loss table ..., actual mi 1.768933775408249
# Best pair to merge : P8YP4---------1, PLYP4---------- with loss : 0.0003986880712027799
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 320
# Computing q and s
# Computing loss table ..., actual mi 1.7685350873370465
# Best pair to merge : P5ZS3--3-------, AANP3----1A---- with loss : 0.0003988101550031736
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 319
# Computing q and s
# Computing loss table ..., actual mi 1.768136277182043
# Best pair to merge : PQ--1----------, P4ZS7---------- with loss : 0.0004078519268030461
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 318
# Computing q and s
# Computing loss table ..., actual mi 1.76772842525524
# Best pair to merge : Vc-S---1-------, Vc-P---1------- with loss : 0.00040798957697498893
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 317
# Computing q and s
# Computing loss table ..., actual mi 1.767320435678265
# Best pair to merge : P4FP4----------, P4XP3---------- with loss : 0.00040958907171718853
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 316
# Computing q and s
# Computing loss table ..., actual mi 1.766910846606548
# Best pair to merge : NNFS5-----A----, NNMS6-----A---- with loss : 0.0004271779262459807
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 315
# Computing q and s
# Computing loss table ..., actual mi 1.766347527285662
# Best pair to merge : P8FS2---------1, CrFS2---------- with loss : 0.00043638533824277956
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 314
# Computing q and s
# Computing loss table ..., actual mi 1.7659111419474194
# Best pair to merge : AGIP2-----A----, AGIS2-----A---- with loss : 0.0004370075353331177
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 313
# Computing q and s
# Computing loss table ..., actual mi 1.7654741344120857
# Best pair to merge : PZ--1----------, AAMP2----1N---- with loss : 0.0004375018816165242
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 312
# Computing q and s
# Computing loss table ..., actual mi 1.7650366325304685
# Best pair to merge : AANS1----2A----, AGNS1-----A---- with loss : 0.00044132968414452474
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 311
# Computing q and s
# Computing loss table ..., actual mi 1.7645953028463244
# Best pair to merge : AGMP2-----A----, PWM-1---------- with loss : 0.0004476530814436525
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 310
# Computing q and s
# Computing loss table ..., actual mi 1.7641476497648803
# Best pair to merge : P5ZS4--3-------, P5FS4--3------- with loss : 0.0004513528272562829
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 309
# Computing q and s
# Computing loss table ..., actual mi 1.7636962969376244
# Best pair to merge : P8IS4----------, PZIS4---------- with loss : 0.0004531512873152128
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 308
# Computing q and s
# Computing loss table ..., actual mi 1.76324314565031
# Best pair to merge : PDFS4----------, AAFS4----2A---- with loss : 0.0004539428902241775
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 307
# Computing q and s
# Computing loss table ..., actual mi 1.7627892027600858
# Best pair to merge : VB-S---1P-NA---, VB-P---1P-NA--- with loss : 0.0004576142049068227
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 306
# Computing q and s
# Computing loss table ..., actual mi 1.7623315885551791
# Best pair to merge : Vi-P---1--A----, VB-S---1P-AA--1 with loss : 0.00045905232374378454
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 305
# Computing q and s
# Computing loss table ..., actual mi 1.7618725362314354
# Best pair to merge : AGFP1-----A----, PLFP1---------- with loss : 0.0004620274366134026
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 304
# Computing q and s
# Computing loss table ..., actual mi 1.7614105087948222
# Best pair to merge : PSMP1-P1-------, ClYP1---------- with loss : 0.0004620423853549981
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 303
# Computing q and s
# Computing loss table ..., actual mi 1.7609484664094677
# Best pair to merge : VB-P---3P-NA--1, VpTP---XR-NA--- with loss : 0.00047099479532538386
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 302
# Computing q and s
# Computing loss table ..., actual mi 1.760477471614142
# Best pair to merge : NNFSX-----A----, A2--------A---- with loss : 0.00047284046257969675
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 301
# Computing q and s
# Computing loss table ..., actual mi 1.7600046311515622
# Best pair to merge : VB-S---3F-NA---, CrFS4---------- with loss : 0.0004751578343252119
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 300
# Computing q and s
# Computing loss table ..., actual mi 1.7595294733172373
# Best pair to merge : PWYS1----------, AGIS1-----A---- with loss : 0.0004776813468598978
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 299
# Computing q and s
# Computing loss table ..., actual mi 1.7590517919703776
# Best pair to merge : AAFS6----1A----, AUFS6M--------- with loss : 0.0004854160260633518
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 298
# Computing q and s
# Computing loss table ..., actual mi 1.7585663759443144
# Best pair to merge : J^------------1, Vi-P---2--A---- with loss : 0.0004894021211215209
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 297
# Computing q and s
# Computing loss table ..., actual mi 1.7580769738231932
# Best pair to merge : VpNS---XR-AA--1, ClZS2---------- with loss : 0.0004902132877675856
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 296
# Computing q and s
# Computing loss table ..., actual mi 1.7575867605354256
# Best pair to merge : PSHP1-P1-------, PSHS1-P1------- with loss : 0.0005005490245994421
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 295
# Computing q and s
# Computing loss table ..., actual mi 1.7570862115108268
# Best pair to merge : PSXP2-P1-------, Cn-P2---------- with loss : 0.0005038918913976842
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 294
# Computing q and s
# Computing loss table ..., actual mi 1.7565823196194288
# Best pair to merge : AAIP1----3A----, PDIP1---------- with loss : 0.0005047323292836936
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 293
# Computing q and s
# Computing loss table ..., actual mi 1.7560775872901444
# Best pair to merge : PSZS1FS3-------, CrNS1---------- with loss : 0.0005089308589285472
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 292
# Computing q and s
# Computing loss table ..., actual mi 1.7555686564312158
# Best pair to merge : Vf--------A---1, PDMP1---------- with loss : 0.0005093865502702512
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 291
# Computing q and s
# Computing loss table ..., actual mi 1.7550592698809462
# Best pair to merge : P8FP4---------1, PDFP4---------- with loss : 0.0005117639054597754
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 290
# Computing q and s
# Computing loss table ..., actual mi 1.754547505975486
# Best pair to merge : Ca--1----------, Ca--4---------- with loss : 0.0005144327983395982
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 289
# Computing q and s
# Computing loss table ..., actual mi 1.7540330731771456
# Best pair to merge : NNMS6-----A---1, P9ZS6---------- with loss : 0.0005204777249476805
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 288
# Computing q and s
# ...
#
# Number of classes : 57
# Computing q and s
# Computing loss table ..., actual mi 1.2475564595701165
# Best pair to merge : P7-X4----------, PHZS4--3------- with loss : 0.00679155373377105
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 56
# Computing q and s
# Computing loss table ..., actual mi 1.2389064213808036
# Best pair to merge : VsYS---XX-AP---, Vf--------A---- with loss : 0.0068111308814650315
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 55
# Computing q and s
# Computing loss table ..., actual mi 1.2314642822630208
# Best pair to merge : NNMS2-----A----, NNNS2-----A---- with loss : 0.007024547833848965
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 54
# Computing q and s
# Computing loss table ..., actual mi 1.2231001181965568
# Best pair to merge : VpYS---XR-AA---, VB-P---1P-AA--- with loss : 0.007204751063766588
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 53
# Computing q and s
# Computing loss table ..., actual mi 1.21502193310065
# Best pair to merge : PSXXXZS3-------, AAMS7----1A---- with loss : 0.007245285207392872
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 52
# Computing q and s
# Computing loss table ..., actual mi 1.2074729761437064
# Best pair to merge : AAFS6----1A----, AAFP6----1A---- with loss : 0.0073230451310112195
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 51
# Computing q and s
# Computing loss table ..., actual mi 1.200149931012696
# Best pair to merge : NNFS6-----A----, NNFP6-----A---- with loss : 0.0022170460257994185
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 50
# Computing q and s
# Computing loss table ..., actual mi 1.197932884986896
# Best pair to merge : AAFP2----1A----, AAIP2----1A---- with loss : 0.007383693238358097
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 49
# Computing q and s
# Computing loss table ..., actual mi 1.1891796567803117
# Best pair to merge : NNFP2-----A----, NNIP2-----A---- with loss : 0.002154279655644388
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 48
# Computing q and s
# Computing loss table ..., actual mi 1.1866961628998591
# Best pair to merge : NNFS4-----A----, NNIS4-----A---- with loss : 0.007751737374023272
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 47
# Computing q and s
# Computing loss table ..., actual mi 1.178942495472506
# Best pair to merge : P8FS4---------1, AAIS4----1A---- with loss : 0.002632142601781297
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 46
# Computing q and s
# Computing loss table ..., actual mi 1.1758980823758138
# Best pair to merge : AAIS2----1A----, AANS2----1A---- with loss : 0.0077579630986458325
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 45
# Computing q and s
# Computing loss table ..., actual mi 1.1676365347928743
# Best pair to merge : NNMS2-----A----, NNIS2-----A---- with loss : 0.0050583271802478735
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 44
# Computing q and s
# Computing loss table ..., actual mi 1.1610440672902753
# Best pair to merge : NNMS7-----A----, NNIP7-----A---- with loss : 0.008278799798829742
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 43
# Computing q and s
# Computing loss table ..., actual mi 1.1526097027831803
# Best pair to merge : PSXXXZS3-------, AAIS7----1A---- with loss : 0.005628035690924901
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 42
# Computing q and s
# Computing loss table ..., actual mi 1.1464594033215347
# Best pair to merge : NNNS1-----A----, NNFS1-----A---- with loss : 0.009118765603192733
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 41
# Computing q and s
# Computing loss table ..., actual mi 1.1370467318050097
# Best pair to merge : AAFS1----1A----, PSHP1-P1------- with loss : 0.0030932301578696017
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 40
# Computing q and s
# Computing loss table ..., actual mi 1.133528728521876
# Best pair to merge : VB-S---3P-AA---, VpYS---XR-AA--- with loss : 0.009162295065406834
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 39
# Computing q and s
# Computing loss table ..., actual mi 1.1246380884967566
# Best pair to merge : C}-------------, C=------------- with loss : 0.012122310766218839
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 38
# Computing q and s
# Computing loss table ..., actual mi 1.1123603105870816
# Best pair to merge : NNFS6-----A----, NNIS6-----A---- with loss : 0.012266748844210917
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 37
# Computing q and s
# Computing loss table ..., actual mi 1.1001327180542428
# Best pair to merge : AAFS6----1A----, AAIS6----1A---- with loss : 0.0026974774592740114
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 36
# Computing q and s
# Computing loss table ..., actual mi 1.0968392318812419
# Best pair to merge : NNMS1-----A----, NNIS1-----A---- with loss : 0.012446246053270132
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 35
# Computing q and s
# Computing loss table ..., actual mi 1.0826463718384753
# Best pair to merge : P8FS4---------1, AAFP4----1A---- with loss : 0.013461169448658009
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 34
# Computing q and s
# Computing loss table ..., actual mi 1.0689879272344562
# Best pair to merge : NNFS4-----A----, NNMP4-----A---- with loss : 0.0025496501716514436
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 33
# Computing q and s
# Computing loss table ..., actual mi 1.0665095263276227
# Best pair to merge : RR--7----------, PSXXXZS3------- with loss : 0.013590135169387101
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 32
# Computing q and s
# Computing loss table ..., actual mi 1.0414806105625862
# Best pair to merge : VB-P---3P-NA---, AAIP1----1A---- with loss : 0.014239132606701402
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 31
# Computing q and s
# Computing loss table ..., actual mi 1.0258512253933165
# Best pair to merge : NNMS1-----A----, PDYS1---------- with loss : 0.014390740672935248
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 30
# Computing q and s
# Computing loss table ..., actual mi 0.9938617156117789
# Best pair to merge : RR--4----------, P8FS4---------1 with loss : 0.015606003224160888
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 29
# Computing q and s
# Computing loss table ..., actual mi 0.9694294440061776
# Best pair to merge : RR--3----------, AAFS1----1A---- with loss : 0.01597475668450476
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 28
# Computing q and s
# Computing loss table ..., actual mi 0.9523147754017345
# Best pair to merge : NNNS1-----A----, NNFP3-----A---- with loss : 0.005832973569290606
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 27
# Computing q and s
# Computing loss table ..., actual mi 0.9467927747820756
# Best pair to merge : Db-------------, P7-X4---------- with loss : 0.016514769180910143
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 26
# Computing q and s
# Computing loss table ..., actual mi 0.9193571687876054
# Best pair to merge : NNMS2-----A----, AAIS2----1A---- with loss : 0.018117050165462698
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 25
# Computing q and s
# Computing loss table ..., actual mi 0.8954504281298818
# Best pair to merge : VB-P---3P-NA---, NNIP1-----A---- with loss : 0.018641232227061016
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 24
# Computing q and s
# Computing loss table ..., actual mi 0.847943935515703
# Best pair to merge : VB-S---3P-AA---, VB-P---3P-NA--- with loss : 0.01658644176702012
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 23
# Computing q and s
# Computing loss table ..., actual mi 0.8329911583724232
# Best pair to merge : AAFS2----1A----, NNFS2-----A---- with loss : 0.019160710820508724
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 22
# Computing q and s
# Computing loss table ..., actual mi 0.7831590716961571
# Best pair to merge : NNMS2-----A----, AAFS2----1A---- with loss : 0.008741172626829455
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 21
# Computing q and s
# Computing loss table ..., actual mi 0.7658085827758455
# Best pair to merge : VsYS---XX-AP---, J^------------- with loss : 0.021378872923430305
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 20
# Computing q and s
# Computing loss table ..., actual mi 0.7427334796713876
# Best pair to merge : NNMS1-----A----, NNNS1-----A---- with loss : 0.0229147308750522
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 19
# Computing q and s
# Computing loss table ..., actual mi 0.718937027088475
# Best pair to merge : RR--2----------, AAFP2----1A---- with loss : 0.024725435225988843
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 18
# Computing q and s
# Computing loss table ..., actual mi 0.6909383051641769
# Best pair to merge : NNMS2-----A----, NNFP2-----A---- with loss : 0.015066168202307557
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 17
# Computing q and s
# Computing loss table ..., actual mi 0.6722777162066809
# Best pair to merge : RR--7----------, RR--3---------- with loss : 0.02574903076723148
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 16
# Computing q and s
# Computing loss table ..., actual mi 0.6465538450388956
# Best pair to merge : NNMS1-----A----, NNMS7-----A---- with loss : 0.015699896100466355
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 15
# Computing q and s
# Computing loss table ..., actual mi 0.6306386275718433
# Best pair to merge : Db-------------, VsYS---XX-AP--- with loss : 0.02554659047077027
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 14
# Computing q and s
# Computing loss table ..., actual mi 0.5967872699855202
# Best pair to merge : NNFS6-----A----, AAFS6----1A---- with loss : 0.03344928437653241
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 13
# Computing q and s
# Computing loss table ..., actual mi 0.5355965682822565
# Best pair to merge : NNMS1-----A----, J,------------- with loss : 0.04132319826765332
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 12
# Computing q and s
# Computing loss table ..., actual mi 0.49421679168700106
# Best pair to merge : Z:-------------, RR--7---------- with loss : 0.042205215545265934
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 11
# Computing q and s
# Computing loss table ..., actual mi 0.44632032762941976
# Best pair to merge : C}-------------, NNMS1-----A---- with loss : 0.03975870924917102
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 10
# Computing q and s
# Computing loss table ..., actual mi 0.412687126787303
# Best pair to merge : RR--4----------, RR--2---------- with loss : 0.044462065432705374
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 9
# Computing q and s
# Computing loss table ..., actual mi 0.36956942087030664
# Best pair to merge : NNFS4-----A----, NNMS2-----A---- with loss : 0.027790944228176614
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 8
# Computing q and s
# Computing loss table ..., actual mi 0.3296675114742046
# Best pair to merge : VB-S---3P-AA---, Db------------- with loss : 0.0495448667627816
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 7
# Computing q and s
# Computing loss table ..., actual mi 0.24237726474673224
# Best pair to merge : C}-------------, VB-S---3P-AA--- with loss : 0.07460321182397076
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 6
# Computing q and s
# Computing loss table ..., actual mi 0.16409490443529928
# Best pair to merge : RR--4----------, RR--6---------- with loss : 0.08149017884347129
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 5
# Computing q and s
# Computing loss table ..., actual mi 0.08335436956219433
# Best pair to merge : NNFS4-----A----, NNFS6-----A---- with loss : 0.029410165570012983
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 4
# Computing q and s
# Computing loss table ..., actual mi 0.056334416612124176
# Best pair to merge : Z:-------------, RR--4---------- with loss : 0.1599944052824825
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 3
# Computing q and s
# Computing loss table ..., actual mi -0.09358945667066976
# Best pair to merge : C}-------------, NNFS4-----A---- with loss : 0.03259062340993095
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 2
# Computing q and s
# Computing loss table ..., actual mi -0.10288227865432427
# Best pair to merge : C}-------------, Z:------------- with loss : 0.2909702897038961
# ----------------------------------------------------------------------------------------------------
#
# Number of classes : 1
